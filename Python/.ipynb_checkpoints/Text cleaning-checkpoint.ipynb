# %%
import re
from nltk.corpus import stopwords

# %%
document = open("C:\\Users\\jianing.a.huang\\OneDrive - Accenture\\Accenture projects\\legal\\0F0Y0V108UD.txt", encoding='utf-8').read()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-32-0ad0bc159f8b> in <module>
# ----> 1 document = open("C:\\Users\\jianing.a.huang\\OneDrive - Accenture\\Accenture projects\\legal\\documents\\Clause collection\\txt\\COLA.txt", encoding='utf-8').read()
#
# ~\AppData\Local\Continuum\anaconda3\envs\smart_legal_pipeline\lib\codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa8 in position 1360: invalid start byte

# %%
def remove(text):
    # remove numbers, special characters, tab
    text = re.sub('[^\w&\s.-]|[0-9\t]','',text)
    text = re.sub('\s+',' ',text)
    return text
    

def process(text):
    text = remove(text).lower()
    text = replaceMultiWordTerms(text, multiWordTerms)
    tokenized_sentence = [[word for word in sentence.strip().split(" ") if word not in stopwords.words("english")] for sentence in text.split(".") if sentence]
    return tokenized_sentence

# %%
process(document)
# Out:
# [['accedahtel',
#   'fax',
#   '-y',
#   'february',
#   'mr',
#   'david',
#   'entwisle',
#   'mutual',
#   'federal',
#   'mutual',
#   'centre',
#   'president',
#   'street',
#   'johannesburg',
#   'south',
#   'africa',
#   'dear',
#   'mr',
#   'entwisle',
#   'arrangement',
#   'claims',
#   'assessment',
#   'data',
#   'analysis',
#   'diagnostic',
#   'pleasure',
#   'presenting',
#   'arrangement',
#   'letter',
#   'conduct',
#   'claims',
#   'diagnostic'],
#  ['recognise',
#   'importance',
#   'project',
#   'would',
#   'like',
#   'thank',
#   'affording',
#   'us',
#   'opportunity',
#   'support',
#   'regard'],
#  ['arrangement',
#   'includes',
#   'claims',
#   'assessment',
#   'detailed',
#   'claims',
#   'data',
#   'analysis',
#   'originally',
#   'discussed',
#   'proposed',
#   'towards',
#   'end',
#   'last',
#   'year'],
#  ['lead',
#   'business',
#   'case',
#   'roadmap',
#   'actions',
#   'realisation',
#   'benefits',
#   'within',
#   'weeks'],
#  ['arrangement',
#   'described',
#   'following',
#   'headings',
#   'context',
#   'objectives',
#   'scope',
#   'approach',
#   'deliverables',
#   'staffing',
#   'critical',
#   'success',
#   'factors',
#   'commercial',
#   'terms',
#   'context',
#   'mutual',
#   'federal',
#   'm&f',
#   'well',
#   'path',
#   'transformation',
#   'programme',
#   'including',
#   'restructuring',
#   'operating',
#   'model',
#   'substantial',
#   'changes',
#   'front',
#   'back',
#   'offices',
#   'support',
#   'services'],
#  ['focus',
#   'date',
#   'non-claims',
#   'expenses',
#   'typical',
#   'general',
#   'insurers',
#   'throughout',
#   'world',
#   'forms',
#   'less',
#   'quarter',
#   'claims',
#   'related',
#   'expenses'],
#  ['workshop',
#   'held',
#   'accenture',
#   'm&f',
#   'exco',
#   'members',
#   'unanimously',
#   'agreed',
#   'exco',
#   'claims',
#   'capability',
#   'examined',
#   'cost',
#   'reduction',
#   'opportunities',
#   'soon',
#   'availability',
#   'm&f',
#   'accenture',
#   'resources',
#   'allow'],
#  ['objectives',
#   'claims',
#   'diagnostic',
#   'provide',
#   'm&f',
#   'deeper',
#   'level',
#   'understanding',
#   'factors',
#   'driving',
#   'current',
#   'level',
#   'performance',
#   'claims',
#   'business',
#   'case',
#   'change',
#   'including',
#   'report',
#   'describing',
#   'areas',
#   'opportunity',
#   'improvement',
#   'terms',
#   'cost',
#   'claims',
#   'view',
#   'overall',
#   'value',
#   'potential',
#   'high-level',
#   'claims',
#   'target',
#   'operating',
#   'model',
#   'describing',
#   'major',
#   'changes',
#   'operation',
#   'required',
#   'achieve',
#   'target',
#   'level',
#   'improvement',
#   'performance',
#   'providing',
#   'input',
#   'initial',
#   'costing',
#   'change',
#   'work',
#   'business',
#   'case',
#   'brings',
#   'together',
#   'costs',
#   'benefits',
#   'potential',
#   'timing',
#   'change',
#   'provides',
#   'suitable',
#   'input',
#   'investment',
#   'decision',
#   'making',
#   'process',
#   'initial',
#   'assessment',
#   'risks',
#   'associated',
#   'change',
#   'high-level',
#   'implementation',
#   'approach',
#   'describing',
#   'potential',
#   'scope',
#   'timing',
#   'series',
#   'phases',
#   'work',
#   'would',
#   'deliver',
#   'change'],
#  ['m&f',
#   'interested',
#   'accenture',
#   'would',
#   'delighted',
#   'arrange',
#   'visit',
#   'another',
#   'relevant',
#   'accenture',
#   'claims',
#   'client',
#   'phase',
#   'project',
#   'providing',
#   'm&f',
#   'opportunity',
#   'discuss',
#   'claims',
#   'change',
#   'peer',
#   'organisation'],
#  ['scope',
#   'based',
#   'discussions',
#   'date',
#   'accenture',
#   'assumes',
#   'scope',
#   'assessment',
#   'focused',
#   'three',
#   'lines',
#   'business',
#   'personal',
#   'commercial',
#   'motor',
#   'personal',
#   'home',
#   'commercial',
#   'property'],
#  ['excluded', 'commercial', 'liability'],
#  ['understanding',
#   'm&f',
#   'recently',
#   'reengineered',
#   'organisation',
#   'structure',
#   'core',
#   'processes'],
#  ['consequently',
#   'excluded',
#   'activity',
#   'based',
#   'costing',
#   'claims',
#   'processes',
#   'scope',
#   'diagnostic',
#   'new',
#   'structures',
#   'processes',
#   'yet',
#   'stabilised'],
#  ['approach',
#   'approach',
#   'diagnostic',
#   'work',
#   'aims',
#   'balance',
#   'need',
#   'establish',
#   'sound',
#   'business',
#   'case',
#   'need',
#   'complete',
#   'required',
#   'analysis',
#   'assessment',
#   'work',
#   'quickly',
#   'feasible'],
#  ['page',
#   'mutual',
#   'federalfebruary',
#   'mind',
#   'accentures',
#   'proposed',
#   'approach',
#   'combines',
#   'use',
#   'improvement',
#   'opportunity',
#   'hypotheses',
#   'derived',
#   'accentures',
#   'prior',
#   'experience',
#   'bottom-up',
#   'review',
#   'claim',
#   'files',
#   'using',
#   'accentures',
#   'proven',
#   'proprietary',
#   'claims',
#   'diagnostic',
#   'tool',
#   'set'],
#  ['high-level',
#   'workplan',
#   'assessment',
#   'planned',
#   'take',
#   'place',
#   'ten',
#   'working',
#   'weeks'],
#  ['figure', 'illustrates', 'key', 'activities', 'would', 'executed', 'period'],
#  ['activity', 'described', 'detail', 'table', 'following', 'figure'],
#  ['week',
#   'week',
#   'week',
#   'week',
#   'week',
#   'week',
#   'week',
#   'week',
#   'week',
#   'week',
#   'mobilisation',
#   'opportunity',
#   'assessmentconclusion',
#   'mobilisation',
#   'hypotheses',
#   'development',
#   'training',
#   'calibration',
#   'claims',
#   'data',
#   'analysis',
#   'technology',
#   'human',
#   'performance',
#   'assessments',
#   'supply',
#   'chain',
#   'assessments',
#   'tom',
#   'bus',
#   'case',
#   'roadmap',
#   'development',
#   'conclude',
#   'communicate',
#   'steercom',
#   'meetings',
#   'aaa',
#   'page',
#   'mutual',
#   'federalfebruary',
#   'phaseoutline',
#   'description',
#   'mobilisationconfirm',
#   'm&f',
#   'resource',
#   'requirementavailability',
#   'establish',
#   'project',
#   'team',
#   'finalise',
#   'logistical',
#   'arrangements',
#   'agree',
#   'governance',
#   'detailed',
#   'schedule'],
#  ['begin',
#   'gathering',
#   'data',
#   'required',
#   'specify',
#   'statistically',
#   'significant',
#   'representative',
#   'sample',
#   'claim',
#   'files',
#   'reviewed'],
#  ['gather',
#   'contextual',
#   'information',
#   'current',
#   'planned',
#   'claims',
#   'operations',
#   'initiatives',
#   'understand',
#   'specific',
#   'business',
#   'model'],
#  ['hypothesesdirect',
#   'observation',
#   'discovery',
#   'interviews',
#   'familiarise',
#   'team',
#   'development',
#   'operations',
#   'identify',
#   'performance',
#   'inhibitors'],
#  ['activity',
#   'would',
#   'typically',
#   'engage',
#   'experienced',
#   'members',
#   'claims',
#   'practice',
#   'participate',
#   'bring',
#   'additional',
#   'expertise',
#   'bear'],
#  ['high-level',
#   'capability',
#   'assessment',
#   'create',
#   'list',
#   'initial',
#   'opportunity',
#   'hypotheses',
#   'supplemented',
#   'accenture',
#   'experience'],
#  ['one-to-one', 'interviews', 'key', 'm&f', 'executives'],
#  ['brainstorming',
#   'sessions',
#   'client',
#   'claims',
#   'handlers',
#   'across',
#   'country',
#   'organization'],
#  ['review',
#   'existing',
#   'information',
#   'previous',
#   'reviews',
#   'cost',
#   'data',
#   'etc'],
#  ['inputs',
#   'would',
#   'fed',
#   'agreed',
#   'set',
#   'opportunities',
#   'best',
#   'practices',
#   'validation',
#   'file',
#   'reviews'],
#  ['select',
#   'agree',
#   'appropriate',
#   'file',
#   'sample',
#   'set',
#   'toolkit',
#   'associated',
#   'procedures',
#   'needed',
#   'run',
#   'next',
#   'phase'],
#  ['work',
#   'm&f',
#   'execs',
#   'claims',
#   'handlers',
#   'tailor',
#   'accentures',
#   'claims',
#   'diagnostic',
#   'questionnaire',
#   'questions',
#   'based',
#   'prior',
#   'global',
#   'experience',
#   'm&f',
#   'context'],
#  ['training',
#   'andmobilise',
#   'induct',
#   'train',
#   'full',
#   'file',
#   'review',
#   'team'],
#  ['calibrate',
#   'team',
#   'calibrationcompleting',
#   'sample',
#   'file',
#   'reviews',
#   'together',
#   'facilitated',
#   'peer',
#   'reviews',
#   'individual',
#   'assessments'],
#  ['engage',
#   'obtain',
#   'understanding',
#   'commitment',
#   'broad',
#   'range',
#   'stakeholders'],
#  ['particular',
#   'finance',
#   'need',
#   'buy-in',
#   'business',
#   'case',
#   'outcomes',
#   'actuarial',
#   'need',
#   'understand',
#   'sampling',
#   'extrapolation',
#   'methods'],
#  ['implement',
#   'robust',
#   'monitoring',
#   'control',
#   'mechanisms',
#   'opportunity',
#   'assessment',
#   'phase'],
#  ['claims',
#   'data',
#   'analysis',
#   'conduct',
#   'deep',
#   'file',
#   'review',
#   'using',
#   'claims',
#   'data',
#   'analysis',
#   'cda',
#   'approach',
#   'review',
#   'closed',
#   'files',
#   '-',
#   'number',
#   'files',
#   'required',
#   'provide',
#   'necessary',
#   'level',
#   'discussed',
#   'agreed',
#   'accenture',
#   'm&f'],
#  ['typically',
#   'involves',
#   'team',
#   'approximately',
#   'experienced',
#   'handlers',
#   'working',
#   '-',
#   'files',
#   'customised',
#   'questionnaire',
#   'designed',
#   'gather',
#   'necessary',
#   'data',
#   'structured',
#   'format'],
#  ['team',
#   'need',
#   'carefully',
#   'consider',
#   'period',
#   'files',
#   'reviewed',
#   'given',
#   'recent',
#   'organisational',
#   'process',
#   'changes',
#   'within',
#   'm&f'],
#  ['results',
#   'input',
#   'accentures',
#   'patented',
#   'claims',
#   'data',
#   'analysis',
#   'toolkittm',
#   'continuously',
#   'analysed',
#   'trends',
#   'patterns'],
#  ['opportunity',
#   'assessment',
#   'deliverable',
#   'go',
#   'multiple',
#   'iterations',
#   'analysis',
#   'complete'],
#  ['exercise',
#   'number',
#   'peer',
#   'reviews',
#   'reviewed',
#   'files',
#   'completed',
#   'results',
#   'fed',
#   'back',
#   'whole',
#   'review',
#   'team',
#   'ensure',
#   'consistency',
#   'feedback',
#   'facilitate',
#   'shared',
#   'learning'],
#  ['technologythe',
#   'team',
#   'use',
#   'accentures',
#   'assessment',
#   'questionnaires'],
#  ['activity',
#   'page',
#   'mutual',
#   'federalfebruary',
#   'phase',
#   'human',
#   'performance',
#   'assessments',
#   'supply',
#   'chain',
#   'assessmentoutline',
#   'description',
#   'identify',
#   'potential',
#   'changes',
#   'm&fs',
#   'current',
#   'operating',
#   'model',
#   'expected',
#   'help',
#   'achieve',
#   'sustain',
#   'improvement'],
#  ['parallel',
#   'core',
#   'opportunity',
#   'assessment',
#   'process',
#   'described',
#   'accenture',
#   'complete',
#   'initial',
#   'analysis',
#   'opportunity',
#   'enhance',
#   'motor',
#   'home',
#   'supply',
#   'chain',
#   'management'],
#  ['area',
#   'claims',
#   'drive',
#   'significant',
#   'reduction',
#   'cost',
#   'claims',
#   'enhance',
#   'customer',
#   'service'],
#  ['tom',
#   'bus',
#   'case',
#   'roadmap',
#   'development',
#   'conclude',
#   'communicatethe',
#   'team',
#   'develop',
#   'high-level',
#   'claims',
#   'target',
#   'operating',
#   'model',
#   'describing',
#   'major',
#   'changes',
#   'operation',
#   'required',
#   'achieve',
#   'target',
#   'level',
#   'improvement',
#   'performance'],
#  ['supported',
#   'business',
#   'case',
#   'high-level',
#   'implementation',
#   'approach',
#   'describing',
#   'potential',
#   'scope',
#   'timing',
#   'series',
#   'phases',
#   'work',
#   'deliver',
#   'change'],
#  ['final',
#   'phase',
#   'brings',
#   'together',
#   'outputs',
#   'preceding',
#   'work',
#   'creates',
#   'opportunity',
#   'assessment',
#   'report',
#   'discussion',
#   'approval',
#   'm&f',
#   'stakeholders'],
#  ['report',
#   'contain',
#   'summary',
#   'findings',
#   'conclusions',
#   'recommendations',
#   'next',
#   'steps'],
#  ['purpose',
#   'steering',
#   'committee',
#   'meetings',
#   'm&f',
#   'stakeholders',
#   'confirm',
#   'scope',
#   'methodology',
#   'hypotheses',
#   'end',
#   'week',
#   'present',
#   'preliminary',
#   'findings',
#   'claims',
#   'data',
#   'analysis',
#   'technology',
#   'hr',
#   'supply',
#   'chain',
#   'assessment',
#   'end',
#   'week',
#   'present',
#   'final',
#   'report',
#   'focus',
#   'target',
#   'operating',
#   'model',
#   'business',
#   'case',
#   'implementation',
#   'plan',
#   'end',
#   'week'],
#  [''],
#  ['deliverables',
#   'deliverables',
#   'claims',
#   'assessment',
#   'diagnostic',
#   'deliverable',
#   'name',
#   'description',
#   'claims',
#   'opportunity',
#   'report',
#   'description',
#   'benefit',
#   'potential',
#   'claims',
#   'bringing',
#   'together',
#   'outputs',
#   'file',
#   'review',
#   'assessment',
#   'activities'],
#  ['high',
#   'level',
#   'target',
#   'operating',
#   'model',
#   'tom',
#   'high',
#   'level',
#   'design',
#   'to-be',
#   'claims',
#   'operation',
#   'describing',
#   'changes',
#   'claims',
#   'process',
#   'organisation',
#   'technology',
#   'sourcing',
#   'could',
#   'implemented',
#   'facilitate',
#   'achievement',
#   'benefits',
#   'identified'],
#  ['business',
#   'case',
#   'business',
#   'case',
#   'describing',
#   'potential',
#   'benefits',
#   'assessmentestimate',
#   'likely',
#   'costs',
#   'associated',
#   'implementing',
#   'change'],
#  ['implementation',
#   'plan',
#   'high',
#   'level',
#   'plan',
#   'implementation',
#   'change',
#   'required',
#   'deliver',
#   'tom'],
#  ['page', 'mutual', 'federalfebruary'],
#  ['staffing',
#   'accenture',
#   'understands',
#   'm&fs',
#   'requirement',
#   'claims',
#   'partner',
#   'focus',
#   'value-add',
#   'activities',
#   'cannot',
#   'easily',
#   'sourced',
#   'internally'],
#  ['anticipated',
#   'include',
#   'provision',
#   'methodology',
#   'toolsets',
#   'analysis',
#   'techniques',
#   'co-management',
#   'analysis',
#   'support',
#   'solution',
#   'design',
#   'support',
#   'regular',
#   'quality',
#   'assurance',
#   'review',
#   'assessment',
#   'work'],
#  ['fulfil',
#   'role',
#   'accenture',
#   'provide',
#   'following',
#   'project',
#   'team',
#   'resource',
#   'level',
#   'duration',
#   'jose',
#   'de',
#   'franca',
#   'insurance',
#   'strategy',
#   'practice',
#   'co-',
#   'manage',
#   'accentures',
#   'contribution',
#   'overall',
#   'project',
#   'shape',
#   'tom',
#   'implementation',
#   'approach',
#   'manager',
#   'days',
#   'pierre',
#   'fourie',
#   'insurance',
#   'practice',
#   'manage',
#   'cda',
#   'analysis',
#   'motor',
#   'lob',
#   'experienced',
#   'consultant',
#   'days',
#   'nahim',
#   'bassa',
#   'crm',
#   'practice',
#   'manage',
#   'cda',
#   'analysis',
#   'personal',
#   'home',
#   'lob',
#   'experienced',
#   'consultant',
#   'days',
#   'michelle',
#   'van',
#   'zyl',
#   'strategy',
#   'practice',
#   'manage',
#   'cda',
#   'analysis',
#   'commercial',
#   'property',
#   'lob',
#   'experienced',
#   'consultant',
#   'days',
#   'darrel',
#   'jamieson',
#   'insurance',
#   'practice',
#   'supply',
#   'chain',
#   'hr',
#   'assessments',
#   'experienced',
#   'consultant',
#   'days',
#   'pieter',
#   'wasserfall',
#   'insurance',
#   'practice',
#   'collate',
#   'data',
#   'develop',
#   'business',
#   'case',
#   'supervision',
#   'project',
#   'managers',
#   'consultant',
#   'days',
#   'katherine',
#   'berchtold',
#   'strategy',
#   'practice',
#   'collate',
#   'data',
#   'support',
#   'review',
#   'process',
#   'analysis',
#   'analyst',
#   'days',
#   'waseem',
#   'vally',
#   'systems',
#   'integration',
#   'technology',
#   'practice',
#   'perform',
#   'technology',
#   'assessment',
#   'experienced',
#   'manager',
#   'days',
#   'graham',
#   'jackson',
#   'uk',
#   'general',
#   'insurance',
#   'practice',
#   'lead',
#   'engagement',
#   'sme',
#   'panel',
#   'senior',
#   'executive',
#   'days',
#   'erwin',
#   'dirnberger',
#   'austrian',
#   'insurance',
#   'practice',
#   'claims',
#   'diagnostic',
#   'sme',
#   'review',
#   'key',
#   'findings',
#   'deliverables',
#   'senior',
#   'manager',
#   'billable',
#   'edmund',
#   'franklin',
#   'insurance',
#   'practice',
#   'overall',
#   'client',
#   'lead',
#   'senior',
#   'executive',
#   'billable',
#   'glenn',
#   'rodgers',
#   'lead',
#   'claims',
#   'business',
#   'across',
#   'europe',
#   'africa',
#   'middle',
#   'east',
#   'claims',
#   'technology',
#   'expert',
#   'sit',
#   'sme',
#   'panel',
#   'review',
#   'key',
#   'findings',
#   'deliverables',
#   'senior',
#   'executive',
#   'billable',
#   'based',
#   'accentures',
#   'experience',
#   'type',
#   'work',
#   'discussion',
#   'activities',
#   'resource',
#   'requirements',
#   'm&f',
#   'believes',
#   'completing',
#   'diagnostic',
#   'project',
#   'would',
#   'require',
#   'approximately',
#   'workdays',
#   'accenture',
#   'effort'],
#  ['level',
#   'accenture',
#   'effort',
#   'dependent',
#   'factors',
#   'lines',
#   'business',
#   'included',
#   'number',
#   'files',
#   'reviewed',
#   'page',
#   'mutual',
#   'federalfebruary',
#   'availability',
#   'm&f',
#   'resources'],
#  ['effort',
#   'estimate',
#   'based',
#   'assumptions',
#   'discuss',
#   'refine',
#   'collaboration',
#   'm&f'],
#  ['m&f',
#   'roles',
#   'resources',
#   'anticipated',
#   'm&f',
#   'provide',
#   'necessary',
#   'input',
#   'project',
#   'order',
#   'make',
#   'best',
#   'use',
#   'time',
#   'available',
#   'including',
#   'project',
#   'management',
#   'experienced',
#   'claims',
#   'handlers',
#   'complete',
#   'file',
#   'reviews',
#   'business',
#   'analysis',
#   'business',
#   'case',
#   'modelling',
#   'resources'],
#  ['following',
#   'resource',
#   'required',
#   'minimum',
#   'one',
#   'senior',
#   'manager',
#   'experience',
#   'claims',
#   'co-manage',
#   'project',
#   'work',
#   'development',
#   'key',
#   'deliverables',
#   '-',
#   'experienced',
#   'claims',
#   'handlers',
#   'line',
#   'business',
#   'review'],
#  ['e'],
#  ['total'],
#  ['handlers',
#   'required',
#   'full-time',
#   'week',
#   'opportunity',
#   'assessment',
#   'phase',
#   'one',
#   'week',
#   'calibration',
#   'phase'],
#  ['cda',
#   'approach',
#   'typically',
#   'requires',
#   '-',
#   'claims',
#   'files',
#   'per',
#   'line',
#   'business',
#   'reviewed',
#   '-',
#   'administrative',
#   'resources',
#   'order',
#   'provide',
#   'manage',
#   'claims',
#   'files',
#   'collect',
#   'administer',
#   'questionnaires',
#   'support',
#   'data',
#   'gathering',
#   'reporting',
#   'one',
#   'appropriately',
#   'skilled',
#   'experienced',
#   'business',
#   'case',
#   'resource',
#   'ensure',
#   'high',
#   'level',
#   'understanding',
#   'ownership',
#   'key',
#   'deliverable',
#   'm&f',
#   'side',
#   'team',
#   'key',
#   'executives',
#   'claims',
#   'handlers',
#   'need',
#   'available',
#   'interviews',
#   'workshops',
#   'especially',
#   'hypothesis',
#   'development',
#   'phase'],
#  ['m&f',
#   'able',
#   'provide',
#   'management',
#   'analysis',
#   'resources',
#   'accenture',
#   'offer',
#   'increase',
#   'level',
#   'resource',
#   'assigned',
#   'project'],
#  ['would',
#   'add',
#   'number',
#   'accenture',
#   'workdays',
#   'impact',
#   'estimated',
#   'fee'],
#  ['accenture',
#   'propose',
#   'make',
#   'short-fall',
#   'm&f',
#   'resource',
#   'required',
#   'review',
#   'claim',
#   'files'],
#  ['work',
#   'needs',
#   'undertaken',
#   'm&fs',
#   'experienced',
#   'claims',
#   'handlers',
#   'valuable'],
#  ['sufficient',
#   'file',
#   'review',
#   'resource',
#   'available',
#   'm&f',
#   'may',
#   'chose',
#   'reduce',
#   'number',
#   'files',
#   'reviewed'],
#  [''],
#  ['critical',
#   'success',
#   'factors',
#   'accenture',
#   'identified',
#   'following',
#   'factors',
#   'believes',
#   'critical',
#   'success',
#   'initial',
#   'diagnostic',
#   'work',
#   'implementation',
#   'work',
#   'may',
#   'follow',
#   'addressed',
#   'capabilities',
#   'approach',
#   'described',
#   'arrangement'],
#  ['success',
#   'factor',
#   'accenture',
#   'approach',
#   'developing',
#   'business',
#   'case',
#   'bottom-up',
#   'identification',
#   'quantification',
#   'opportunities',
#   'credible',
#   'supportedthat',
#   'specific',
#   'm&f',
#   'fact',
#   'cross-check',
#   'm&f',
#   'opportunities',
#   'accentures',
#   'experience',
#   'claims',
#   're-engineering',
#   'making',
#   'best',
#   'use',
#   'short',
#   'time',
#   'window'],
#  ['use',
#   'improvement',
#   'opportunity',
#   'hypotheses',
#   'accelerate',
#   'findings',
#   'study',
#   'focus',
#   'areas',
#   'highest',
#   'probability',
#   'success',
#   'joint',
#   'use',
#   'm&f',
#   'accenture',
#   'experience',
#   'focus',
#   'areas',
#   'shown',
#   'deliver',
#   'value',
#   'clients',
#   'use',
#   'proven',
#   'tools',
#   'techniques',
#   'minimise',
#   're-',
#   'page',
#   'mutual',
#   'federalfebruary',
#   'success',
#   'factoraccenture',
#   'approach',
#   'inventing',
#   'wheel',
#   'assignment',
#   'experienced',
#   'skilled',
#   'resources',
#   'perform',
#   'reviews',
#   'tight',
#   'planning',
#   'monitored',
#   'execution',
#   'key',
#   'analysis',
#   'tasks',
#   'box',
#   'tools',
#   'training',
#   'plans',
#   'etc'],
#  ['need',
#   'tailored',
#   'local',
#   'context',
#   'rather',
#   'built',
#   'scratch',
#   'developing',
#   'balanced',
#   'view',
#   'use',
#   'claims',
#   'opportunity',
#   'assessment',
#   'framework',
#   'potential',
#   'impact',
#   'ofaccounts',
#   'changes',
#   'settlement',
#   'cost',
#   'handling',
#   'expense',
#   'changecustomer',
#   'service',
#   'employee',
#   'satisfaction'],
#  ['settlement',
#   'costs',
#   'far',
#   'biggest',
#   'value',
#   'lever',
#   'short',
#   'term',
#   'insurance',
#   'company',
#   'typically',
#   '-',
#   'total',
#   'costs',
#   'approach',
#   'provide',
#   'focus',
#   'settlement',
#   'cost',
#   'reductions',
#   'critical',
#   'success',
#   'm&f',
#   'also',
#   'accounting',
#   'opportunity',
#   'dimensions',
#   'applying',
#   'challenging',
#   'focus',
#   'achieving',
#   'breadth',
#   'depth',
#   'challenge',
#   'supportive',
#   'work',
#   'stylecurrent',
#   'thinking',
#   'practice',
#   'required',
#   'identify',
#   'potential',
#   'improvement',
#   'tools',
#   'techniques',
#   'supple',
#   'enough',
#   'accommodate',
#   'needs',
#   'apply',
#   'pragmatism',
#   'apply',
#   'joint',
#   'experience',
#   'claims',
#   'identify',
#   'well-defined',
#   'analysis',
#   'benefitdiscrete',
#   'understandable',
#   'improvements',
#   'would',
#   'required',
#   'achieve',
#   'benefit',
#   'focus',
#   'identifying',
#   'benefit',
#   'within',
#   'reach',
#   'based',
#   'realistic',
#   'level',
#   'change',
#   'clear',
#   'alignment',
#   'objectives',
#   'fact',
#   'base',
#   'supports',
#   'opportunity',
#   'assessment',
#   'm&f',
#   'accenturederived',
#   'employees',
#   'complete',
#   'objectivity',
#   'size',
#   'nature',
#   'opportunity',
#   'prepared',
#   'work',
#   'riskreward',
#   'commercial',
#   'structure',
#   'appropriate',
#   'similar',
#   'arrangements',
#   'applied',
#   'subsequent',
#   'change',
#   'implementation',
#   'workactive',
#   'm&f',
#   'executive',
#   'sponsorship',
#   'project',
#   'dedication',
#   'required',
#   'm&f',
#   'resources',
#   'critical'],
#  ['page', 'mutual', 'federalfebruary'],
#  ['commercial',
#   'terms',
#   'based',
#   'accentures',
#   'estimate',
#   'resource',
#   'effort',
#   'required',
#   'complete',
#   'work',
#   'described',
#   'document',
#   'agreed',
#   'rate',
#   'card',
#   'per',
#   'settlement',
#   'agreement',
#   'spice',
#   'insurance',
#   'limited',
#   'accenture',
#   'south',
#   'africa',
#   'pty',
#   'limited',
#   'settlement',
#   'agreement',
#   'fee',
#   'engagement',
#   'r'],
#  ['million', 'exclusive', 'expenses', 'vat'],
#  ['accentures',
#   'past',
#   'experience',
#   'gives',
#   'good',
#   'reason',
#   'believe',
#   'compelling',
#   'business',
#   'case',
#   'indicated',
#   'opportunities',
#   'within',
#   'm&fs',
#   'claims',
#   'capability'],
#  ['often',
#   'substantial',
#   'component',
#   'benefit',
#   'found',
#   'organisational',
#   'changes',
#   'involving',
#   'limited',
#   'implementation'],
#  ['quick', 'wins', 'realised', 'within', 'relatively', 'short', 'time'],
#  ['accenture',
#   'move',
#   'forward',
#   'm&f',
#   'significant',
#   'implementation',
#   'work',
#   'area',
#   'claims',
#   'accenture',
#   'prepared',
#   'offer',
#   'services',
#   'flexible',
#   'commercial',
#   'arrangements',
#   'fixed',
#   'price',
#   'subject',
#   'agreed',
#   'terms',
#   'outcomes',
#   'based',
#   'pricing',
#   'linking',
#   'part',
#   'fee',
#   'level',
#   'benefit',
#   'identified'],
#  ['accenture',
#   'pleased',
#   'refine',
#   'estimate',
#   'm&f',
#   'accounting',
#   'scope',
#   'timing',
#   'm&f',
#   'resource',
#   'availability'],
#  ['invoices', 'payable', 'per', 'terms', 'settlement', 'agreement'],
#  ['trust',
#   'letter',
#   'provides',
#   'information',
#   'require',
#   'confirm',
#   'arrangement'],
#  ['require',
#   'information',
#   'clarify',
#   'proposition',
#   'please',
#   'contact',
#   'edmund',
#   'franklin',
#   '-',
#   '--',
#   'sincerely',
#   'graham',
#   'jackson',
#   'senior',
#   'executive',
#   'financial',
#   'services',
#   'page',
#   'mutual',
#   'federalfebruary',
#   'signed',
#   'agreement',
#   'behalf'],
#  ['mutu'],
#  ['alser-v-atral', 'signature', 'date', '--', 'name', 'print'],
#  ['r-'],
#  ['signed',
#   'agreement',
#   'behalf',
#   'accenture',
#   'signature',
#   'date',
#   'name',
#   'print'],
#  ['utsk', 'page', 'mutual', 'federalfebruary']]

# %%
multiWordTerms = ['cost of living adjustments', 'cost of living adjustment']
def replaceMultiWordTerms(text, multiWordTerms):
    # This function takes a string and a list of multiword terms and replaces each occurrence
    # a multiword term with the term having spaces replaced by '_' e.g. Cost Of Living Adjustment
    # will be replaced with Cost_Of_Living_Adjustment
    for term in multiWordTerms:

        text = text.replace(term, term.replace(' ', '_'))

    return text

# %%
processed_document = process(document)
content = replaceMultiWordTerms(processed_document, multiWordTerms)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-f13c4e489234> in <module>
#       1 processed_document = process(document)
# ----> 2 content = replaceMultiWordTerms(processed_document, multiWordTerms)
#
# <ipython-input-27-48fbdd0afbbc> in replaceMultiWordTerms(text, multiWordTerms)
#       6     for term in multiWordTerms:
#       7
# ----> 8         text = text.replace(term, term.replace(' ', '_'))
#       9
#      10     return text
#
# AttributeError: 'list' object has no attribute 'replace'
