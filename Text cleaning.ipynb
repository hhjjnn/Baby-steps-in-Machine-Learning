# %%
import re

# %%
document = open("0F0Y0V108UD.txt",encoding='utf-8').read()

# %%
def remove(text):
    text = re.sub('[0-9\t]','',text)
    return text

# %%
#tokenize paragraphs
def return_paragraph(text):
    paragraphs = [paragraph for paragraph in text.split("\n") if paragraph]
    return paragraphs

# %%
processed_document = return_paragraph(remove(document))

# %%
processed_document
# Out:
# ['accedahTel: +    • FAX: +  -y',
#  'February , ',
#  'Mr David Entwisle',
#  'Mutual and Federal',
#  'Mutual Centre',
#  ' President Street',
#  'Johannesburg',
#  'South Africa',
#  'Dear Mr Entwisle,',
#  'ARRANGEMENT FOR CLAIMS ASSESSMENT AND DATA ANALYSIS (DIAGNOSTIC)',
#  'We have pleasure in presenting our arrangement letter to conduct a Claims Diagnostic. We recognise the importance of this project and would like to thank you for affording us the opportunity to support you in this regard.',
#  'This arrangement includes both the Claims Assessment and the detailed Claims Data Analysis originally discussed and proposed towards the end of last year. These lead to a business case and roadmap of actions for realisation of the benefits within  weeks.',
#  'This arrangement is described under the following headings:',
#  'Context',
#  'Objectives',
#  'Scope',
#  'Approach',
#  'Deliverables',
#  'Staffing',
#  'Critical Success Factors',
#  'Commercial Terms',
#  'CONTEXT',
# ...

# %%
import string
punct = set(string.punctuation)

# %%
punct.remove('-')

# %%
punct;

# %%
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize

# %%
document = remove_numbers(document)

# %%
# Out:
# ['accedah\tTel: +    • FAX: +  -y', 'February , ', 'Mr David Entwisle', 'Mutual and Federal', 'Mutual Centre', ' President Street', 'Johannesburg', 'South Africa', 'Dear Mr Entwisle,', 'ARRANGEMENT FOR CLAIMS ASSESSMENT AND DATA ANALYSIS (DIAGNOSTIC)', 'We have pleasure in presenting our arrangement letter to conduct a Claims Diagnostic. We recognise the importance of this project and would like to thank you for affording us the opportunity to support you in this regard.', 'This arrangement includes both the Claims Assessment and the detailed Claims Data Analysis originally discussed and proposed towards the end of last year. These lead to a business case and roadmap of actions for realisation of the benefits within  weeks.', 'This arrangement is described under the following headings:', '\t\tContext', '\t\tObjectives', '\t\tScope', '\t\tApproach', '\t\tDeliverables', '\t\tStaffing', '\t\tCritical Success Factors', '\t\tCommercial Terms', '\t\tCONTEXT', 'Mutual and Federal (M&F) are 
# ...

# %%
[w for w in word_tokenize(document) if w not in punct]
# Out:
# ['accedah',
#  'Tel',
#  '•',
#  'FAX',
#  '-y',
#  'February',
#  'Mr',
#  'David',
#  'Entwisle',
#  'Mutual',
#  'and',
#  'Federal',
#  'Mutual',
#  'Centre',
#  'President',
#  'Street',
#  'Johannesburg',
#  'South',
#  'Africa',
#  'Dear',
#  'Mr',
#  'Entwisle',
#  'ARRANGEMENT',
#  'FOR',
#  'CLAIMS',
#  'ASSESSMENT',
#  'AND',
#  'DATA',
#  'ANALYSIS',
#  'DIAGNOSTIC',
#  'We',
#  'have',
#  'pleasure',
#  'in',
#  'presenting',
#  'our',
#  'arrangement',
#  'letter',
#  'to',
#  'conduct',
#  'a',
#  'Claims',
#  'Diagnostic',
#  'We',
#  'recognise',
#  'the',
#  'importance',
#  'of',
#  'this',
#  'project',
#  'and',
#  'would',
#  'like',
#  'to',
#  'thank',
#  'you',
#  'for',
#  'affording',
#  'us',
#  'the',
#  'opportunity',
#  'to',
#  'support',
#  'you',
#  'in',
#  'this',
#  'regard',
#  'This',
#  'arrangement',
#  'includes',
#  'both',
#  'the',
#  'Claims',
#  'Assessment',
#  'and',
#  'the',
#  'detailed',
#  'Claims',
#  'Data',
#  'Analysis',
# ...
